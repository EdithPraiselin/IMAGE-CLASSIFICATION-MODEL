# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array
from google.colab import files

# Load and preprocess the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Classes in the dataset
class_names = ['airplane', 'automobile', 'bird', 'cat',
               'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Build the CNN model
model = tf.keras.Sequential([
    layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(10, activation='softmax')  # 10 classes for CIFAR-10
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model for 5 epochs
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 524s 333ms/step - accuracy: 0.2605 - loss: 1.9490 - val_accuracy: 0.5122 - val_loss: 1.3161
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 582s 346ms/step - accuracy: 0.5472 - loss: 1.2533 - val_accuracy: 0.6260 - val_loss: 1.0517
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 540s 332ms/step - accuracy: 0.6444 - loss: 1.0042 - val_accuracy: 0.6710 - val_loss: 0.9349
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 538s 344ms/step - accuracy: 0.7014 - loss: 0.8465 - val_accuracy: 0.6980 - val_loss: 0.8755
# Epoch 5/5
# ...

# %%
# Import required libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.utils import img_to_array, load_img
from sklearn.metrics import classification_report

# Path to your dataset folder
dataset_path = "/content/drive/MyDrive/Test_dataset"  # Change this to your actual dataset folder

# Load test dataset (Ensure it has 50 images)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    image_size=(32, 32),  # Resize images to match model input
    batch_size=1,  # Process one image at a time
    shuffle=False  # Keep order for consistent comparison
)

# Get class names
class_names = test_dataset.class_names
print("Classes found:", class_names)

# Normalize images
normalization_layer = tf.keras.layers.Rescaling(1./255)
test_dataset = test_dataset.map(lambda x, y: (normalization_layer(x), y))

# Lists for storing actual and predicted labels
y_true = []
y_pred = []

# ---------------------
# ✅ Display Results
# ---------------------
plt.figure(figsize=(15, 10))  # Adjust size for 50 images

for i, (images, labels) in enumerate(test_dataset):
    if i >= 50:  # Ensure we only process 50 images
        break

    # Predict the class
    predictions = model.predict(images)
    predicted_class_index = np.argmax(predictions)
    predicted_class_name = class_names[predicted_class_index]

    # Store actual and predicted labels
    y_true.append(labels.numpy()[0])
    y_pred.append(predicted_class_index)

    # Display the image with predicted label
    plt.subplot(5, 10, i + 1)  # Ensure 5x10 grid layout
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[0].numpy())

    # ✅ Color Prediction Text (Green if correct, Red if wrong)
    actual_class_name = class_names[y_true[-1]]
    color = "green" if actual_class_name == predicted_class_name else "red"
    plt.xlabel(f"Pred: {predicted_class_name}", color=color)

plt.tight_layout()
plt.show()

# ---------------------
# ✅ Print Classification Report
# ---------------------
y_true = np.array(y_true)
print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Found 50 files belonging to 10 classes.
# Classes found: ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ...
